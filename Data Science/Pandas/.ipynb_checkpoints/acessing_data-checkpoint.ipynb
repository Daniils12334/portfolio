# %%
df.loc[2-1]
# Out:
# ID                                   2
# Age                                 69
# Gender                            Male
# Height_cm                          156
# Weight_kg                           82
# BMI                              20.86
# Daily_Steps                      12803
# Calories_Intake                   1650
# Hours_of_Sleep                     4.5
# Heart_Rate                         103
# Blood_Pressure                  129/65
# Exercise_Hours_per_Week            3.7
# Smoker                              No
# Alcohol_Consumption_per_Week         7
# Diabetic                            No
# Heart_Disease                       No
# Name: 1, dtype: object

# %%
import pandas as pd

# %%
df = pd.read_csv('/home/danbar/Desktop/project_x/health_activity_data.csv')

# %%
df.iloc[1]
# Out:
# ID                                   2
# Age                                 69
# Gender                            Male
# Height_cm                          156
# Weight_kg                           82
# BMI                              20.86
# Daily_Steps                      12803
# Calories_Intake                   1650
# Hours_of_Sleep                     4.5
# Heart_Rate                         103
# Blood_Pressure                  129/65
# Exercise_Hours_per_Week            3.7
# Smoker                              No
# Alcohol_Consumption_per_Week         7
# Diabetic                            No
# Heart_Disease                       No
# Name: 1, dtype: object

# %%
df.loc[14, 'Age']
# Out:
# np.int64(41)

# %%
df.iat[1,1]
# Out:
# np.int64(69)

# %%
df.at[1,'Age'] = 69

# %%
df
# Out:
#        ID  Age  Gender  Height_cm  Weight_kg    BMI  Daily_Steps  \
# 0       1   56    Male        164         81  30.72         5134
# 1       2   69    Male        156         82  20.86        12803
# 2       3   46  Female        158         65  30.93        16408
# 3       4   32    Male        197         87  31.19        18420
# 4       5   60    Male        157         63  29.37        17351
# ..    ...  ...     ...        ...        ...    ...          ...
# 995   996   18    Male        179        116  31.67        10095
# 996   997   35  Female        170        114  23.88        11361
# 997   998   49  Female        169         85  23.44         9531
# 998   999   64    Male        155         74  22.34         5270
# 999  1000   66  Female        171         86  20.64        10906
#
#      Calories_Intake  Hours_of_Sleep  Heart_Rate Blood_Pressure  \
# 0               1796             8.6         102         137/72
# ...

# %%
# df.loc['John'] = [90, ...] thats will add john with used parameters

# %%
df.iloc[0:8]
# Out:
#    ID  Age  Gender  Height_cm  Weight_kg    BMI  Daily_Steps  Calories_Intake  \
# 0   1   56    Male        164         81  30.72         5134             1796
# 1   2   69    Male        156         82  20.86        12803             1650
# 2   3   46  Female        158         65  30.93        16408             1756
# 3   4   32    Male        197         87  31.19        18420             2359
# 4   5   60    Male        157         63  29.37        17351             2556
# 5   6   25  Female        199         85  31.14         5131             3256
# 6   7   78    Male        172         72  32.46        19532             2216
# 7   8   38    Male        178        115  28.62        13057             3262
#
#    Hours_of_Sleep  Heart_Rate Blood_Pressure  Exercise_Hours_per_Week Smoker  \
# 0             8.6         102         137/72                      8.1     No
# 1             4.5         103         129/65                      3.7     No
# ...
