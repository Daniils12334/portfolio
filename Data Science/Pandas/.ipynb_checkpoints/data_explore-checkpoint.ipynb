# %%
import pandas as pd

# %%
data_frame = pd.read_csv('/home/danbar/Desktop/project_x/health_activity_data.csv')

# %%
data_frame.head(3)
# Out:
#    ID  Age  Gender  Height_cm  Weight_kg    BMI  Daily_Steps  Calories_Intake  \
# 0   1   56    Male        164         81  30.72         5134             1796
# 1   2   69    Male        156         82  20.86        12803             1650
# 2   3   46  Female        158         65  30.93        16408             1756
#
#    Hours_of_Sleep  Heart_Rate Blood_Pressure  Exercise_Hours_per_Week Smoker  \
# 0             8.6         102         137/72                      8.1     No
# 1             4.5         103         129/65                      3.7     No
# 2             4.3          74         127/68                      3.2    Yes
#
#    Alcohol_Consumption_per_Week Diabetic Heart_Disease
# 0                             7       No            No
# 1                             7       No            No
# 2                             0       No            No

# %%
data_frame.tail(1)
# Out:
#        ID  Age  Gender  Height_cm  Weight_kg    BMI  Daily_Steps  \
# 999  1000   66  Female        171         86  20.64        10906
#
#      Calories_Intake  Hours_of_Sleep  Heart_Rate Blood_Pressure  \
# 999             1284             8.5          72         118/83
#
#      Exercise_Hours_per_Week Smoker  Alcohol_Consumption_per_Week Diabetic  \
# 999                      1.3     No                             1       No
#
#     Heart_Disease
# 999            No

# %%
list(data_frame.columns)
# Out:
# ['ID',
#  'Age',
#  'Gender',
#  'Height_cm',
#  'Weight_kg',
#  'BMI',
#  'Daily_Steps',
#  'Calories_Intake',
#  'Hours_of_Sleep',
#  'Heart_Rate',
#  'Blood_Pressure',
#  'Exercise_Hours_per_Week',
#  'Smoker',
#  'Alcohol_Consumption_per_Week',
#  'Diabetic',
#  'Heart_Disease']

# %%
pd.options.display.max_columns = 6


data_frame
# Out:
#        ID  Age  Gender  ...  Alcohol_Consumption_per_Week  Diabetic  \
# 0       1   56    Male  ...                             7        No
# 1       2   69    Male  ...                             7        No
# 2       3   46  Female  ...                             0        No
# 3       4   32    Male  ...                             5        No
# 4       5   60    Male  ...                             8        No
# ..    ...  ...     ...  ...                           ...       ...
# 995   996   18    Male  ...                             5        No
# 996   997   35  Female  ...                             3        No
# 997   998   49  Female  ...                             4        No
# 998   999   64    Male  ...                             4        No
# 999  1000   66  Female  ...                             1        No
#
#      Heart_Disease
# 0               No
# 1               No
# 2               No
# 3               No
# 4               No
# ..             ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            1000 non-null   int64
#  1   Age                           1000 non-null   int64
#  2   Gender                        1000 non-null   object
#  3   Height_cm                     1000 non-null   int64
#  4   Weight_kg                     1000 non-null   int64
#  5   BMI                           1000 non-null   float64
#  6   Daily_Steps                   1000 non-null   int64
#  7   Calories_Intake               1000 non-null   int64
#  8   Hours_of_Sleep                1000 non-null   float64
#  9   Heart_Rate                    1000 non-null   int64
#  10  Blood_Pressure                1000 non-null   object
#  11  Exercise_Hours_per_Week       1000 non-null   float64
# ...
