# %%
import pandas as pd

# %%
df = pd.read_csv('/home/danbar/Desktop/project_x/health_activity_data.csv')

# %%
df = df.reset_index()

# %%
import datetime as dt
df.Age = df.Age.fillna(df.Age.mean())
df['birthday'] = df['Age'].apply(lambda x: dt.datetime.now() - dt.timedelta(days=365*x))

# %%
df.query('Age > 30') #numexpr
# Out:
#      index    ID   Age  Gender  Height_cm  Weight_kg    BMI  Daily_Steps  \
# 0        0     1  56.0    Male        164         81  30.72         5134
# 2        2     3  46.0  Female        158         65  30.93        16408
# 3        3     4  32.0    Male        197         87  31.19        18420
# 4        4     5  60.0    Male        157         63  29.37        17351
# 6        6     7  78.0    Male        172         72  32.46        19532
# ..     ...   ...   ...     ...        ...        ...    ...          ...
# 994    994   995  71.0  Female        150         56  23.09        12410
# 996    996   997  35.0  Female        170        114  23.88        11361
# 997    997   998  49.0  Female        169         85  23.44         9531
# 998    998   999  64.0    Male        155         74  22.34         5270
# 999    999  1000  66.0  Female        171         86  20.64        10906
#
#      Calories_Intake  Hours_of_Sleep  Heart_Rate Blood_Pressure  \
# ...

# %%
ages = [50,70]

df[df.Age.isin(ages)]
# Out:
#      index   ID   Age  Gender  Height_cm  Weight_kg    BMI  Daily_Steps  \
# 15      15   16  70.0    Male        188        117  20.33        13158
# 21      21   22  70.0    Male        193         64  23.44         3011
# 30      30   31  50.0    Male        193         79  22.33        14757
# 70      70   71  70.0    Male        154         69  19.27         6509
# 119    119  120  70.0  Female        154         54  25.37        16632
# 146    146  147  50.0  Female        160         90  18.74         3828
# 159    159  160  50.0    Male        189        108  27.06         2848
# 221    221  222  70.0    Male        188         74  33.19         5567
# 237    237  238  50.0    Male        190         70  26.08        10107
# 254    254  255  50.0    Male        177         92  30.24        13427
# 291    291  292  50.0  Female        181         65  20.07         5298
# 296    296  297  70.0  Female        195         53  20.46        15391
# ...

# %%
df[df.birthday.dt.year > 2000]
# Out:
#      index   ID   Age  Gender  Height_cm  Weight_kg    BMI  Daily_Steps  \
# 1        1    2   0.0    Male        156         82  20.86        12803
# 19      19   20  20.0  Female        173         71  34.26        12905
# 22      22   23  19.0    Male        194        109  19.77         4373
# 27      27   28  19.0    Male        189         94  19.70         2289
# 54      54   55  20.0    Male        181         52  32.07         4915
# ..     ...  ...   ...     ...        ...        ...    ...          ...
# 977    977  978  23.0    Male        161         59  31.98         4124
# 980    980  981  22.0  Female        161         70  19.90        18737
# 983    983  984  19.0  Female        152         73  21.98         1924
# 990    990  991  22.0  Female        154         68  34.56        12781
# 995    995  996  18.0    Male        179        116  31.67        10095
#
#      Calories_Intake  Hours_of_Sleep  Heart_Rate Blood_Pressure  \
# ...

# %%
df[df.Smoker.str.endswith('s')]
# Out:
#      index   ID   Age  Gender  Height_cm  Weight_kg    BMI  Daily_Steps  \
# 2        2    3  46.0  Female        158         65  30.93        16408
# 4        4    5  60.0    Male        157         63  29.37        17351
# 6        6    7  78.0    Male        172         72  32.46        19532
# 7        7    8  38.0    Male        178        115  28.62        13057
# 9        9   10  75.0    Male        180        114  26.55        12486
# ..     ...  ...   ...     ...        ...        ...    ...          ...
# 975    975  976  52.0  Female        179        116  19.61         7559
# 978    978  979  35.0  Female        166         91  32.57         9671
# 981    981  982  64.0    Male        157        115  24.86        13070
# 986    986  987  47.0  Female        194         79  22.93        14650
# 988    988  989  76.0  Female        177         96  21.26        16310
#
#      Calories_Intake  Hours_of_Sleep  Heart_Rate Blood_Pressure  \
# ...

# %%
df.Age[0:9] > 45
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# 8     True
# Name: Age, dtype: bool

# %%
df[(df.Age > 60) & (df.Hours_of_Sleep > 7)]
# Out:
#        ID   Age  Gender  Height_cm  Weight_kg    BMI  Daily_Steps  \
# 6       7  78.0    Male        172         72  32.46        19532
# 9      10  75.0    Male        180        114  26.55        12486
# 24     25  61.0    Male        152         98  31.61        11692
# 32     33  75.0  Female        164        116  31.76         8657
# 47     48  64.0    Male        191        103  25.91         4103
# ..    ...   ...     ...        ...        ...    ...          ...
# 985   986  73.0    Male        179        105  26.24         6506
# 987   988  67.0    Male        172        106  20.17         3395
# 988   989  76.0  Female        177         96  21.26        16310
# 989   990  62.0  Female        189         84  20.93         9226
# 999  1000  66.0  Female        171         86  20.64        10906
#
#      Calories_Intake  Hours_of_Sleep  Heart_Rate Blood_Pressure  \
# 6               2216             9.6          95          96/86
# ...

# %%
df[df.Age > 78][0:10]
# Out:
#       ID   Age  Gender  Height_cm  Weight_kg    BMI  Daily_Steps  \
# 45    46  79.0  Female        151        115  33.16         8692
# 46    47  79.0    Male        184         74  26.80        12088
# 48    49  79.0  Female        183         82  28.17         3440
# 89    90  79.0  Female        198         58  34.41         1719
# 101  102  79.0  Female        162         85  31.06        13100
# 112  113  79.0    Male        192         51  25.64        19931
# 163  164  79.0  Female        183         94  31.25         3786
# 219  220  79.0  Female        192         67  23.29        11848
# 229  230  79.0    Male        161         70  34.31        10590
# 236  237  79.0  Female        198         62  31.81        10497
#
#      Calories_Intake  Hours_of_Sleep  Heart_Rate Blood_Pressure  \
# 45              2013             5.6          59         111/83
# 46              2472             6.1          74         120/81
# ...

# %%
df.at[1, 'Age'] = float('nan')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            1000 non-null   int64
#  1   Age                           999 non-null    float64
#  2   Gender                        1000 non-null   object
#  3   Height_cm                     1000 non-null   int64
#  4   Weight_kg                     1000 non-null   int64
#  5   BMI                           1000 non-null   float64
#  6   Daily_Steps                   1000 non-null   int64
#  7   Calories_Intake               1000 non-null   int64
#  8   Hours_of_Sleep                1000 non-null   float64
#  9   Heart_Rate                    1000 non-null   int64
#  10  Blood_Pressure                1000 non-null   object
#  11  Exercise_Hours_per_Week       1000 non-null   float64
# ...

# %%
# df.dropna() # delete all values which contains Not a Number / NaN 
# df.fillna(0) # replace NaN values with 0
df.Age.fillna(round(df.Age.mean(), 0))
# Out:
# 0      56.0
# 1      50.0
# 2      46.0
# 3      32.0
# 4      60.0
#        ...
# 995    18.0
# 996    35.0
# 997    49.0
# 998    64.0
# 999    66.0
# Name: Age, Length: 1000, dtype: float64

# %%
df[df.Age.notna()]
# Out:
#        ID   Age  Gender  Height_cm  Weight_kg    BMI  Daily_Steps  \
# 0       1  56.0    Male        164         81  30.72         5134
# 2       3  46.0  Female        158         65  30.93        16408
# 3       4  32.0    Male        197         87  31.19        18420
# 4       5  60.0    Male        157         63  29.37        17351
# 5       6  25.0  Female        199         85  31.14         5131
# ..    ...   ...     ...        ...        ...    ...          ...
# 995   996  18.0    Male        179        116  31.67        10095
# 996   997  35.0  Female        170        114  23.88        11361
# 997   998  49.0  Female        169         85  23.44         9531
# 998   999  64.0    Male        155         74  22.34         5270
# 999  1000  66.0  Female        171         86  20.64        10906
#
#      Calories_Intake  Hours_of_Sleep  Heart_Rate Blood_Pressure  \
# 0               1796             8.6         102         137/72
# ...

# %%
for i, col in df.items():
    print(i)
# Out:
# ID
# Age
# Gender
# Height_cm
# Weight_kg
# BMI
# Daily_Steps
# Calories_Intake
# Hours_of_Sleep
# Heart_Rate
# Blood_Pressure
# Exercise_Hours_per_Week
# Smoker
# Alcohol_Consumption_per_Week
# Diabetic
# Heart_Disease

# %%
for i, col in df.items():
    print(col)
# Out:
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5
#        ...
# 995     996
# 996     997
# 997     998
# 998     999
# 999    1000
# Name: ID, Length: 1000, dtype: int64
# 0      56.0
# 1       NaN
# 2      46.0
# 3      32.0
# 4      60.0
#        ...
# 995    18.0
# 996    35.0
# 997    49.0
# 998    64.0
# 999    66.0
# Name: Age, Length: 1000, dtype: float64
# 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 995      Male
# 996    Female
# 997    Female
# 998      Male
# 999    Female
# Name: Gender, Length: 1000, dtype: object
# 0      164
# 1      156
# 2      158
# 3      197
# 4      157
#       ...
# 995    179
# 996    170
# 997    169
# 998    155
# 999    171
# Name: Height_cm, Length: 1000, dtype: int64
# 0       81
# 1       82
# 2       65
# 3       87
# 4       63
#       ...
# 995    116
# 996    114
# 997     85
# 998     74
# 999     86
# Name: Weight_kg, Length: 1000, dtype: int64
# 0      30.72
# ...

# %%
for i, row in df.iterrows():
    print(row)
# Out:
# ID                                   1
# Age                               56.0
# Gender                            Male
# Height_cm                          164
# Weight_kg                           81
# BMI                              30.72
# Daily_Steps                       5134
# Calories_Intake                   1796
# Hours_of_Sleep                     8.6
# Heart_Rate                         102
# Blood_Pressure                  137/72
# Exercise_Hours_per_Week            8.1
# Smoker                              No
# Alcohol_Consumption_per_Week         7
# Diabetic                            No
# Heart_Disease                       No
# Name: 0, dtype: object
# ID                                   2
# Age                                NaN
# Gender                            Male
# Height_cm                          156
# Weight_kg                           82
# BMI                              20.86
# Daily_Steps                      12803
# ...
