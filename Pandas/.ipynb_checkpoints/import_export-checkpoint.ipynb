# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    'age': [18,19,17],
    'name': ['Daniils','Arturs','Aleksandrs'],
    'job': ['Student','Waiter','Student'] 
})
df = df.set_index('age')

# %%
df
# Out:
#            name      job
# age
# 18      Daniils  Student
# 19       Arturs   Waiter
# 17   Aleksandrs  Student

# %%
df = df.reset_index()

# %%
df
# Out:
#    age        name      job
# 0   18     Daniils  Student
# 1   19      Arturs   Waiter
# 2   17  Aleksandrs  Student

# %%
df.to_csv('mydata.csv', index = None)

# %%
pd.read_csv('mydata.csv', index_col=0)
# Out:
#            name      job
# age
# 18      Daniils  Student
# 19       Arturs   Waiter
# 17   Aleksandrs  Student

# %%
df.to_json('mydata.json')

# %%
df.to_dict()
# Out:
# {'age': {0: 18, 1: 19, 2: 17},
#  'name': {0: 'Daniils', 1: 'Arturs', 2: 'Aleksandrs'},
#  'job': {0: 'Student', 1: 'Waiter', 2: 'Student'}}

# %%
np.save('mydata.npy', df.to_numpy(dtype=object))

# %%
data = np.load('mydata.npy', allow_pickle=True)

# %%
data
# Out:
# array([[18, 'Daniils', 'Student'],
#        [19, 'Arturs', 'Waiter'],
#        [17, 'Aleksandrs', 'Student']], dtype=object)

# %%
data = pd.read_csv('/home/danbar/Desktop/project_x/health_activity_data.csv')

# %%
data.head(10)
# Out:
#    ID  Age  Gender  Height_cm  Weight_kg    BMI  Daily_Steps  Calories_Intake  \
# 0   1   56    Male        164         81  30.72         5134             1796
# 1   2   69    Male        156         82  20.86        12803             1650
# 2   3   46  Female        158         65  30.93        16408             1756
# 3   4   32    Male        197         87  31.19        18420             2359
# 4   5   60    Male        157         63  29.37        17351             2556
# 5   6   25  Female        199         85  31.14         5131             3256
# 6   7   78    Male        172         72  32.46        19532             2216
# 7   8   38    Male        178        115  28.62        13057             3262
# 8   9   56    Male        167         51  19.96        12349             2038
# 9  10   75    Male        180        114  26.55        12486             2837
#
#    Hours_of_Sleep  Heart_Rate Blood_Pressure  Exercise_Hours_per_Week Smoker  \
# ...

# %%
data.tail(3)
# Out:
#        ID  Age  Gender  Height_cm  Weight_kg    BMI  Daily_Steps  \
# 997   998   49  Female        169         85  23.44         9531
# 998   999   64    Male        155         74  22.34         5270
# 999  1000   66  Female        171         86  20.64        10906
#
#      Calories_Intake  Hours_of_Sleep  Heart_Rate Blood_Pressure  \
# 997             2416             4.5          80         125/65
# 998             2080             5.8         101         129/86
# 999             1284             8.5          72         118/83
#
#      Exercise_Hours_per_Week Smoker  Alcohol_Consumption_per_Week Diabetic  \
# 997                      7.6     No                             4       No
# 998                      5.4     No                             4       No
# 999                      1.3     No                             1       No
#
#     Heart_Disease
# 997            No
# 998            No
# 999            No
