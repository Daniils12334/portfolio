# %%
import pandas as pd

# %%
df = pd.read_csv('/home/danbar/Desktop/project_x/health_activity_data.csv')

# %%
df.Age ** 2
# Out:
# 0      3136
# 1      4761
# 2      2116
# 3      1024
# 4      3600
#        ...
# 995     324
# 996    1225
# 997    2401
# 998    4096
# 999    4356
# Name: Age, Length: 1000, dtype: int64

# %%
df.Age = df.Age ** 2

# %%
df.Age = df.Age.apply(lambda x: x**0.5) # or df.Age = df.Age ** 0.5

# %%
df
# Out:
#        ID   Age  Gender  Height_cm  Weight_kg    BMI  Daily_Steps  \
# 0       1  56.0    Male        164         81  30.72         5134
# 1       2  69.0    Male        156         82  20.86        12803
# 2       3  46.0  Female        158         65  30.93        16408
# 3       4  32.0    Male        197         87  31.19        18420
# 4       5  60.0    Male        157         63  29.37        17351
# ..    ...   ...     ...        ...        ...    ...          ...
# 995   996  18.0    Male        179        116  31.67        10095
# 996   997  35.0  Female        170        114  23.88        11361
# 997   998  49.0  Female        169         85  23.44         9531
# 998   999  64.0    Male        155         74  22.34         5270
# 999  1000  66.0  Female        171         86  20.64        10906
#
#      Calories_Intake  Hours_of_Sleep  Heart_Rate Blood_Pressure  \
# 0               1796             8.6         102         137/72
# ...

# %%
def my_function(x):
    if x % 3 == 0:
        return x ** 2
    else:
        return x // 2

# %%
def my_function2(x):
    if x.startswith('M'):
        return 'Nice Cock! '
    else:
        return 'Without "Nice Cock!"'

# %%
df.Age.apply(my_function)
# Out:
# 0        28.0
# 1      4761.0
# 2        23.0
# 3        16.0
# 4      3600.0
#         ...
# 995     324.0
# 996      17.0
# 997      24.0
# 998      32.0
# 999    4356.0
# Name: Age, Length: 1000, dtype: float64

# %%
df.Gender.apply(my_function2)
# Out:
# 0               Nice Cock!
# 1               Nice Cock!
# 2      Without "Nice Cock!"
# 3               Nice Cock!
# 4               Nice Cock!
#                ...
# 995             Nice Cock!
# 996    Without "Nice Cock!"
# 997    Without "Nice Cock!"
# 998             Nice Cock!
# 999    Without "Nice Cock!"
# Name: Gender, Length: 1000, dtype: object

# %%
df.Age.apply(lambda x: x**2 if x % 10 == 0 else x // 2)
# Out:
# 0        28.0
# 1        34.0
# 2        23.0
# 3        16.0
# 4      3600.0
#         ...
# 995       9.0
# 996      17.0
# 997      24.0
# 998      32.0
# 999      33.0
# Name: Age, Length: 1000, dtype: float64

# %%
df['summary'] = df.apply(lambda row: f'Age: {row["Age"]}, Diabetic: {row["Diabetic"]}', axis=1)

# %%
df = df.drop(['summary', 'Smoker'] ,axis=1)

# %%
df
# Out:
#        ID   Age  Gender  Height_cm  Weight_kg    BMI  Daily_Steps  \
# 0       1  56.0    Male        164         81  30.72         5134
# 1       2  69.0    Male        156         82  20.86        12803
# 2       3  46.0  Female        158         65  30.93        16408
# 3       4  32.0    Male        197         87  31.19        18420
# 4       5  60.0    Male        157         63  29.37        17351
# ..    ...   ...     ...        ...        ...    ...          ...
# 995   996  18.0    Male        179        116  31.67        10095
# 996   997  35.0  Female        170        114  23.88        11361
# 997   998  49.0  Female        169         85  23.44         9531
# 998   999  64.0    Male        155         74  22.34         5270
# 999  1000  66.0  Female        171         86  20.64        10906
#
#      Calories_Intake  Hours_of_Sleep  Heart_Rate Blood_Pressure  \
# 0               1796             8.6         102         137/72
# ...
